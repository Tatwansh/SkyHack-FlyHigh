# %% [markdown]
# # SkyHigh EDA on all the 4 dataset calls, sentiment, customer,resasons.

# %% [markdown]
# ## EDA of the calls dataset

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV=AutoViz_Class()
import matplotlib.pyplot as plt
# %matplotlib inline
df=r"C:\Users\plaks\Downloads\callsf0d4f5a.csv"
dft= AV.AutoViz(df)
# Out:
# Shape of your Data Set loaded: (71810, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  4
#     Number of Date Time Columns =  0
#     Number of ID Columns =  2
#     Number of Columns to Delete =  0
#     7 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['call_id', 'customer_id']
# ...

# %% [markdown]
# ## EDA of the customer dataset

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV=AutoViz_Class()
import matplotlib.pyplot as plt
# %matplotlib inline
df=r"C:\Users\plaks\Downloads\customers2afd6ea.csv"
df2= AV.AutoViz(df)
# Out:
# Shape of your Data Set loaded: (71810, 3)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     3 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['customer_id']
# ...

# %% [markdown]
# ## EDA of the sentiment dataset

# %% [markdown]
# from autoviz.AutoViz_Class import AutoViz_Class
#
# AV=AutoViz_Class()
# import matplotlib.pyplot as plt
# %matplotlib inline
# df=r"C:\Users\plaks\Downloads\sentiment_statisticscc1e57a.csv"
# df2= AV.AutoViz(df)

# %% [markdown]
# ## EDA of the reason dataset

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV=AutoViz_Class()
import matplotlib.pyplot as plt
# %matplotlib inline
df=r"C:\Users\plaks\Downloads\reason18315ff.csv"
df2= AV.AutoViz(df)
# Out:
# Shape of your Data Set loaded: (66653, 2)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     2 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['call_id']
# ...

# %%
"C:\Users\plaks\Downloads\reason18315ff.csv"
