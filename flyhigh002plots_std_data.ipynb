# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Read csv files
customers=pd.read_csv("customers.csv")
call_records=pd.read_csv("calls.csv")
reason2call=pd.read_csv("reason.csv")
test=pd.read_csv("test.csv")
sent=pd.read_csv("sentiment.csv")

# %%
# Class encoding for sentiments with negative and positive values
cleanup_nums = {"agent_tone":     {"angry": -1, "frustrated": -2, "neutral": 0, "calm": 1, "polite": 2},
                "customer_tone": {"angry": -1, "frustrated": -2, "neutral": 0, "calm": 1, "polite": 2}}
sent = sent.replace(cleanup_nums)
# Out:
# C:\Users\plaks\AppData\Local\Temp\ipykernel_15616\3887140760.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sent = sent.replace(cleanup_nums)

# %%
sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71810 entries, 0 to 71809
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  71810 non-null  int64
#  1   agent_id                 71810 non-null  int64
#  2   agent_tone               71593 non-null  float64
#  3   customer_tone            71810 non-null  int64
#  4   average_sentiment        71701 non-null  float64
#  5   silence_percent_average  71810 non-null  float64
# dtypes: float64(3), int64(3)
# memory usage: 3.3 MB

# %%
#found unique reasons
reason2call["primary_call_reason"]=reason2call["primary_call_reason"].str.replace(r"\s+"," ",regex=True)
r=reason2call["primary_call_reason"].unique()
print(len(r))
print(r)
# Out:
# 44
# ['Voluntary Cancel' 'Booking' 'IRROPS' 'Upgrade' 'Seating' 'Mileage Plus'
#  'Checkout' 'Voluntary Change' 'Post Flight' 'Check In' 'Other Topics'
#  'Communications' 'Schedule Change' 'Products & Services' 'IRROPS '
#  'Digital Support' 'Seating ' 'Disability' 'Unaccompanied Minor'
#  ' Baggage' 'Traveler Updates' 'Communications ' 'ETC' 'Upgrade '
#  'Unaccompanied Minor ' 'Voluntary Change ' 'Checkout ' 'Mileage Plus '
#  'Booking ' 'Baggage ' 'Post-Flight' 'Post-Flight ' 'Schedule Change '
#  'Baggage' 'Check-In' 'Products and Services' 'Check-In ' 'Other Topics '
#  'ETC ' 'Disability ' 'Digital Support ' 'Voluntary Cancel '
#  'Products and Services ' 'Traveler Updates ']

# %%
# Categorical Encoding using sklearn
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
reason2call["primary_call_reason_ord"] = ord_enc.fit_transform(reason2call[["primary_call_reason"]])
reason2call.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66653 entries, 0 to 66652
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  66653 non-null  int64
#  1   primary_call_reason      66653 non-null  object
#  2   primary_call_reason_ord  66653 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
reason2call.head()
# Out:
#       call_id primary_call_reason  primary_call_reason_ord
# 0  4667960400    Voluntary Cancel                     40.0
# 1  1122072124             Booking                      3.0
# 2  6834291559              IRROPS                     18.0
# 3  2266439882             Upgrade                     38.0
# 4  1211603231             Seating                     32.0

# %%
call_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71810 entries, 0 to 71809
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  71810 non-null  int64
#  1   customer_id              71810 non-null  int64
#  2   agent_id                 71810 non-null  int64
#  3   call_start_datetime      71810 non-null  object
#  4   agent_assigned_datetime  71810 non-null  object
#  5   call_end_datetime        71810 non-null  object
#  6   call_transcript          71810 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 3.8+ MB

# %%
#Str to datetime
call_records["call_start_datetime"]=pd.to_datetime(call_records["call_start_datetime"])
call_records["agent_assigned_datetime"]=pd.to_datetime(call_records["agent_assigned_datetime"])
call_records["call_end_datetime"]=pd.to_datetime(call_records["call_end_datetime"])

# %%
call_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71810 entries, 0 to 71809
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  71810 non-null  int64
#  1   customer_id              71810 non-null  int64
#  2   agent_id                 71810 non-null  int64
#  3   call_start_datetime      71810 non-null  datetime64[ns]
#  4   agent_assigned_datetime  71810 non-null  datetime64[ns]
#  5   call_end_datetime        71810 non-null  datetime64[ns]
#  6   call_transcript          71810 non-null  object
# dtypes: datetime64[ns](3), int64(3), object(1)
# memory usage: 3.8+ MB

# %%
# found waiting time and handling time
call_records["WaitTime"]=(call_records["agent_assigned_datetime"]-call_records["call_start_datetime"]).dt.total_seconds()/60
call_records["HandlingTime"]=(call_records["call_end_datetime"]-call_records["agent_assigned_datetime"]).dt.total_seconds()/60
call_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71810 entries, 0 to 71809
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  71810 non-null  int64
#  1   customer_id              71810 non-null  int64
#  2   agent_id                 71810 non-null  int64
#  3   call_start_datetime      71810 non-null  datetime64[ns]
#  4   agent_assigned_datetime  71810 non-null  datetime64[ns]
#  5   call_end_datetime        71810 non-null  datetime64[ns]
#  6   call_transcript          71810 non-null  object
#  7   WaitTime                 71810 non-null  float64
#  8   HandlingTime             71810 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(3), object(1)
# memory usage: 4.9+ MB

# %%
call_records.head()
# Out:
#       call_id  customer_id  agent_id call_start_datetime  \
# 0  4667960400   2033123310    963118 2024-07-31 23:56:00
# 1  1122072124   8186702651    519057 2024-08-01 00:03:00
# 2  6834291559   2416856629    158319 2024-07-31 23:59:00
# 3  2266439882   1154544516    488324 2024-08-01 00:05:00
# 4  1211603231   5214456437    721730 2024-08-01 00:04:00
#
#   agent_assigned_datetime   call_end_datetime  \
# 0     2024-08-01 00:03:00 2024-08-01 00:34:00
# 1     2024-08-01 00:06:00 2024-08-01 00:18:00
# 2     2024-08-01 00:07:00 2024-08-01 00:26:00
# 3     2024-08-01 00:10:00 2024-08-01 00:17:00
# 4     2024-08-01 00:14:00 2024-08-01 00:23:00
#
#                                      call_transcript  WaitTime  HandlingTime
# 0  \n\nAgent: Thank you for calling United Airlin...       7.0          31.0
# 1  \n\nAgent: Thank you for calling United Airlin...       3.0          12.0
# 2  \n\nAgent: Thank you for calling United Airlin...       8.0          19.0
# 3  \n\nAgent: Thank you for calling United Airlin...       5.0           7.0
# 4  \n\nAgent: Thank you for calling United Airlin...      10.0           9.0

# %%
#Merged dataset
merged_df = pd.merge(call_records, reason2call, on="call_id", how="inner")
merged_df = pd.merge(merged_df, sent, on="call_id", how="inner")
merged_df.head()
# Out:
#       call_id  customer_id  agent_id_x call_start_datetime  \
# 0  4667960400   2033123310      963118 2024-07-31 23:56:00
# 1  1122072124   8186702651      519057 2024-08-01 00:03:00
# 2  6834291559   2416856629      158319 2024-07-31 23:59:00
# 3  2266439882   1154544516      488324 2024-08-01 00:05:00
# 4  1211603231   5214456437      721730 2024-08-01 00:04:00
#
#   agent_assigned_datetime   call_end_datetime  \
# 0     2024-08-01 00:03:00 2024-08-01 00:34:00
# 1     2024-08-01 00:06:00 2024-08-01 00:18:00
# 2     2024-08-01 00:07:00 2024-08-01 00:26:00
# 3     2024-08-01 00:10:00 2024-08-01 00:17:00
# 4     2024-08-01 00:14:00 2024-08-01 00:23:00
#
#                                      call_transcript  WaitTime  HandlingTime  \
# 0  \n\nAgent: Thank you for calling United Airlin...       7.0          31.0
# 1  \n\nAgent: Thank you for calling United Airlin...       3.0          12.0
# 2  \n\nAgent: Thank you for calling United Airlin...       8.0          19.0
# 3  \n\nAgent: Thank you for calling United Airlin...       5.0           7.0
# 4  \n\nAgent: Thank you for calling United Airlin...      10.0           9.0
#
#   primary_call_reason  primary_call_reason_ord  agent_id_y  agent_tone  \
# 0    Voluntary Cancel                     40.0      963118         0.0
# 1             Booking                      3.0      519057         1.0
# 2              IRROPS                     18.0      158319         0.0
# 3             Upgrade                     38.0      488324         0.0
# 4             Seating                     32.0      721730         0.0
#
#    customer_tone  average_sentiment  silence_percent_average
# 0             -1              -0.04                     0.39
# 1              0               0.02                     0.35
# 2              2              -0.13                     0.32
# 3             -2              -0.20                     0.20
# 4              2              -0.05                     0.35

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66653 entries, 0 to 66652
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  66653 non-null  int64
#  1   customer_id              66653 non-null  int64
#  2   agent_id_x               66653 non-null  int64
#  3   call_start_datetime      66653 non-null  datetime64[ns]
#  4   agent_assigned_datetime  66653 non-null  datetime64[ns]
#  5   call_end_datetime        66653 non-null  datetime64[ns]
#  6   call_transcript          66653 non-null  object
#  7   WaitTime                 66653 non-null  float64
#  8   HandlingTime             66653 non-null  float64
#  9   primary_call_reason      66653 non-null  object
#  10  primary_call_reason_ord  66653 non-null  float64
#  11  agent_id_y               66653 non-null  int64
#  12  agent_tone               66455 non-null  float64
#  13  customer_tone            66653 non-null  int64
#  14  average_sentiment        66552 non-null  float64
#  15  silence_percent_average  66653 non-null  float64
# dtypes: datetime64[ns](3), float64(6), int64(5), object(2)
# memory usage: 8.1+ MB

# %%
# Correlation heatmap
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

# Import file with data
data = merged_df

# Plotting correlation heatmap
dataplot = sb.heatmap(data.corr(numeric_only=True), cmap="YlGnBu", annot=True)

# Displaying heatmap
mp.show()

# %%
# drop datetime and object attributes
merged_df_numeric = merged_df.select_dtypes(include=[np.number])
merged_df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66653 entries, 0 to 66652
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_id                  66653 non-null  int64
#  1   customer_id              66653 non-null  int64
#  2   agent_id_x               66653 non-null  int64
#  3   WaitTime                 66653 non-null  float64
#  4   HandlingTime             66653 non-null  float64
#  5   primary_call_reason_ord  66653 non-null  float64
#  6   agent_id_y               66653 non-null  int64
#  7   agent_tone               66455 non-null  float64
#  8   customer_tone            66653 non-null  int64
#  9   average_sentiment        66552 non-null  float64
#  10  silence_percent_average  66653 non-null  float64
# dtypes: float64(6), int64(5)
# memory usage: 5.6 MB

# %%
merged_df_numeric.skew()
# Out:
# call_id                    0.007545
# customer_id               -0.002201
# agent_id_x                -0.094180
# WaitTime                   0.089539
# HandlingTime               2.759415
# primary_call_reason_ord    0.003558
# agent_id_y                -0.094180
# agent_tone                -1.223135
# customer_tone             -0.001705
# average_sentiment         -0.338113
# silence_percent_average    0.638877
# dtype: float64

# %%
import matplotlib.pyplot as plt
merged_df.plot("primary_call_reason_ord","WaitTime")
plt.show()

# %%
merged_df.plot("primary_call_reason_ord","HandlingTime")
plt.show()

# %%
merged_df.plot("HandlingTime","customer_tone")
plt.show()

# %%
merged_df.plot("HandlingTime","agent_tone")
plt.show()

# %% [markdown]
# # PLOTTED THE GRAPH AND DID EDA ON MERGED DATASET WITHOUT SCALING

# %%
# !pip install autoviz
# Out:
# Requirement already satisfied: autoviz in c:\users\plaks\anaconda3\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: wordcloud in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.9.3)
# Requirement already satisfied: emoji in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (2.12.1)
# Requirement already satisfied: pyamg in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (5.2.1)
# Requirement already satisfied: scikit-learn in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.4.2)
# Requirement already satisfied: statsmodels in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (0.14.2)
# Requirement already satisfied: nltk in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (3.8.1)
# Requirement already satisfied: textblob in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (0.18.0.post0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (2024.3.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (4.11.0)
# Requirement already satisfied: pandas-dq>=1.29 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.26.4)
# Requirement already satisfied: hvplot>=0.9.2 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (0.10.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.19.0)
# Requirement already satisfied: panel>=1.4.0 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (1.4.4)
# Requirement already satisfied: pandas>=2.0 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (3.8.4)
# Requirement already satisfied: seaborn>0.12.2 in c:\users\plaks\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in c:\users\plaks\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.4.1)
# Requirement already satisfied: colorcet in c:\users\plaks\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in c:\users\plaks\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (23.2)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\plaks\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\plaks\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\plaks\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\plaks\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\plaks\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2023.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2022.9.0)
# Requirement already satisfied: markdown in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.66.4)
# Requirement already satisfied: bleach in c:\users\plaks\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\plaks\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\plaks\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\plaks\anaconda3\lib\site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: click in c:\users\plaks\anaconda3\lib\site-packages (from nltk->autoviz) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\plaks\anaconda3\lib\site-packages (from nltk->autoviz) (2023.10.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\plaks\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.6)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\plaks\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\plaks\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\plaks\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.1)
# Requirement already satisfied: six in c:\users\plaks\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: colorama in c:\users\plaks\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.4.0->autoviz) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\plaks\anaconda3\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\plaks\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\plaks\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\plaks\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\plaks\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\plaks\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\plaks\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\plaks\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.1.3)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV=AutoViz_Class()
import matplotlib.pyplot as plt
# %matplotlib inline
df=merged_df_numeric
dft= AV.AutoViz(df)
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (66653, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  6
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  2
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['call_id', 'customer_id']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_f2afb_row0_col0, #T_f2afb_row0_col2, #T_f2afb_row0_col5, #T_f2afb_row1_col0, #T_f2afb_row1_col2, #T_f2afb_row1_col5, #T_f2afb_row2_col0, #T_f2afb_row2_col2, #T_f2afb_row2_col5, #T_f2afb_row3_col0, #T_f2afb_row3_col2, #T_f2afb_row3_col5, #T_f2afb_row4_col0, #T_f2afb_row4_col2, #T_f2afb_row4_col5, #T_f2afb_row5_col0, #T_f2afb_row5_col2, #T_f2afb_row5_col5, #T_f2afb_row6_col0, #T_f2afb_row6_col2, #T_f2afb_row6_col5, #T_f2afb_row7_col0, #T_f2afb_row7_col2, #T_f2afb_row7_col5, #T_f2afb_row8_col0, #T_f2afb_row8_col2, #T_f2afb_row8_col5, #T_f2afb_row9_col0, #T_f2afb_row9_col2, #T_f2afb_row9_col5, #T_f2afb_row10_col0, #T_f2afb_row10_col2, #T_f2afb_row10_col5 {
#   font-family: Segoe UI;
# }
# #T_f2afb_row0_col1, #T_f2afb_row1_col1, #T_f2afb_row2_col1, #T_f2afb_row2_col4, #T_f2afb_row3_col1, #T_f2afb_row3_col3, #T_f2afb_row3_col4, #T_f2afb_row4_col1, #T_f2afb_row4_col3, #T_f2afb_row4_col4, #T_f2afb_row5_col1, #T_f2afb_row5_col3, #T_f2afb_row5_col4, #T_f2afb_row6_col1, #T_f2afb_row6_col4, #T_f2afb_row7_col3, #T_f2afb_row7_col4, #T_f2afb_row8_col1, #T_f2afb_row8_col3, #T_f2afb_row8_col4, #T_f2afb_row9_col3, #T_f2afb_row9_col4, #T_f2afb_row10_col1, #T_f2afb_row10_col3, #T_f2afb_row10_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f2afb_row0_col3 {
#   background-color: #fcab8f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f2afb_row0_col4, #T_f2afb_row1_col3, #T_f2afb_row1_col4, #T_f2afb_row7_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_f2afb_row2_col3, #T_f2afb_row6_col3 {
#   background-color: #fcc1a8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_f2afb_row9_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_f2afb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2afb_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_f2afb_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_f2afb_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_f2afb_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_f2afb_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_f2afb_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2afb_level0_row0" class="row_heading level0 row0" >call_id</th>
#       <td id="T_f2afb_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_f2afb_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f2afb_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_f2afb_row0_col3" class="data row0 col3" >131642.000000</td>
#       <td id="T_f2afb_row0_col4" class="data row0 col4" >9999806100.000000</td>
#       <td id="T_f2afb_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row1" class="row_heading level0 row1" >customer_id</th>
#       <td id="T_f2afb_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_f2afb_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_f2afb_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_f2afb_row1_col3" class="data row1 col3" >443070.000000</td>
#       <td id="T_f2afb_row1_col4" class="data row1 col4" >9999935113.000000</td>
#       <td id="T_f2afb_row1_col5" class="data row1 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row2" class="row_heading level0 row2" >agent_id_x</th>
#       <td id="T_f2afb_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_f2afb_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_f2afb_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f2afb_row2_col3" class="data row2 col3" >102574.000000</td>
#       <td id="T_f2afb_row2_col4" class="data row2 col4" >993862.000000</td>
#       <td id="T_f2afb_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row3" class="row_heading level0 row3" >WaitTime</th>
#       <td id="T_f2afb_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_f2afb_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_f2afb_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_f2afb_row3_col3" class="data row3 col3" >3.000000</td>
#       <td id="T_f2afb_row3_col4" class="data row3 col4" >15.000000</td>
#       <td id="T_f2afb_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row4" class="row_heading level0 row4" >HandlingTime</th>
#       <td id="T_f2afb_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_f2afb_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_f2afb_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_f2afb_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_f2afb_row4_col4" class="data row4 col4" >119.000000</td>
#       <td id="T_f2afb_row4_col5" class="data row4 col5" >Column has 4700 outliers greater than upper bound (31.50) or lower than lower bound(-12.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row5" class="row_heading level0 row5" >primary_call_reason_ord</th>
#       <td id="T_f2afb_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_f2afb_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_f2afb_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_f2afb_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f2afb_row5_col4" class="data row5 col4" >43.000000</td>
#       <td id="T_f2afb_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row6" class="row_heading level0 row6" >agent_id_y</th>
#       <td id="T_f2afb_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_f2afb_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_f2afb_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_f2afb_row6_col3" class="data row6 col3" >102574.000000</td>
#       <td id="T_f2afb_row6_col4" class="data row6 col4" >993862.000000</td>
#       <td id="T_f2afb_row6_col5" class="data row6 col5" >Column has a high correlation with ['agent_id_x']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row7" class="row_heading level0 row7" >agent_tone</th>
#       <td id="T_f2afb_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_f2afb_row7_col1" class="data row7 col1" >0.297061</td>
#       <td id="T_f2afb_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_f2afb_row7_col3" class="data row7 col3" >-2.000000</td>
#       <td id="T_f2afb_row7_col4" class="data row7 col4" >2.000000</td>
#       <td id="T_f2afb_row7_col5" class="data row7 col5" >198 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 3438 outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them., Column has a high correlation with ['average_sentiment']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row8" class="row_heading level0 row8" >customer_tone</th>
#       <td id="T_f2afb_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_f2afb_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_f2afb_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_f2afb_row8_col3" class="data row8 col3" >-2.000000</td>
#       <td id="T_f2afb_row8_col4" class="data row8 col4" >2.000000</td>
#       <td id="T_f2afb_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f2afb_level0_row9" class="row_heading level0 row9" >average_sentiment</th>
#       <td id="T_f2afb_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_f2afb_row9_col1" class="data row9 col1" >0.151531</td>
#       <td id="T_f2afb_row9_col2" class="data row9 col2" >NA</td>
# Number of All Scatter Plots = 21
# All Plots done
# Time to run AutoViz = 16 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
merged_df_numeric.head()
# Out:
#      call_id   customer_id  agent_id_x  WaitTime  HandlingTime  \
# 0  4667960400  2033123310     963118       7.0        31.0
# 1  1122072124  8186702651     519057       3.0        12.0
# 2  6834291559  2416856629     158319       8.0        19.0
# 3  2266439882  1154544516     488324       5.0         7.0
# 4  1211603231  5214456437     721730      10.0         9.0
#
#    primary_call_reason_ord  agent_id_y  agent_tone  customer_tone  \
# 0           40.0              963118        0.0          -1
# 1            3.0              519057        1.0           0
# 2           18.0              158319        0.0           2
# 3           38.0              488324        0.0          -2
# 4           32.0              721730        0.0           2
#
#    average_sentiment  silence_percent_average
# 0       -0.04                  0.39
# 1        0.02                  0.35
# 2       -0.13                  0.32
# 3       -0.20                  0.20
# 4       -0.05                  0.35

# %% [markdown]
# ## plotting the grphs of important features

# %%
import seaborn as sns
cols = ['HandlingTime','WaitTime','silence_percent_average','primary_call_reason_ord']
x=1

plt.figure(figsize=(20,35))
for i in cols:
    plt.subplot(6,2,x)
    sns.distplot(merged_df_numeric[i],color="green")
    plt.title(f"{i} Distribution")
    plt.tight_layout()
    x+=1

# these are the pdf plots of those features

# %%
cols = ["customer_tone","agent_tone"]

plt.figure(figsize=(18,6))
for idx,column in enumerate(cols):
    plt.subplot(1,2,idx+1)
    sns.countplot(x=column, data=merged_df_numeric, palette="Set2")
    plt.title(f"{column} Distribution")
    plt.tight_layout()

# Class encoding for sentiments with negative and positive values
# for reference
"""cleanup_nums = {"agent_tone":     {"angry": -1, "frustrated": -2, "neutral": 0, "calm": 1, "polite": 2},
                "customer_tone": {"angry": -1, "frustrated": -2, "neutral": 0, "calm": 1, "polite": 2}}"""
# Out:
# 'cleanup_nums = {"agent_tone":     {"angry": -1, "frustrated": -2, "neutral": 0, "calm": 1, "polite": 2},\n                "customer_tone": {"angry": -1, "frustrated": -2, "neutral": 0, "calm": 1, "polite": 2}}'

# %% [markdown]
# # NOW LETS MAKE THIS DATASET STANDARDIZED AND NORMALIZED FOR FEW FEATURES COLUMNS AND THEN DO EDA AND PLOT THE ABOVE GRAPHS

# %%
# standardization and normalization of the data
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import preprocessing

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler
merged_df_numeric.columns
# Out:
# Index(['call_id', 'customer_id', 'agent_id_x', 'WaitTime', 'HandlingTime',
#        'primary_call_reason_ord', 'agent_id_y', 'agent_tone', 'customer_tone',
#        'average_sentiment', 'silence_percent_average'],
#       dtype='object')

# %%
""" standardizing features by removing the mean and scaling to unit variance."""
stdscaler=StandardScaler()
standard_scaler_merged_data=pd.DataFrame(stdscaler.fit_transform(merged_df_numeric),columns=['call_id', 'customer_id', 'agent_id_x', 'WaitTime', 'HandlingTime',
       'primary_call_reason_ord', 'agent_id_y', 'agent_tone', 'customer_tone',
       'average_sentiment', 'silence_percent_average'
      ])
standard_scaler_merged_data
# Out:
#         call_id  customer_id  agent_id_x  WaitTime  HandlingTime  \
# 0     -0.112790  -1.031185     1.547602  -0.112283    1.501733
# 1     -1.339892   1.102837    -0.176964  -1.700066    0.029475
# 2      0.636898  -0.898109    -1.577935   0.284662    0.571886
# 3     -0.943868  -1.335870    -0.296320  -0.906175   -0.357961
# 4     -1.308909   0.072081     0.610142   1.078554   -0.202986
# ...         ...          ...         ...       ...           ...
# 66648  0.891409   0.818675     0.849804  -0.509229   -0.125499
# 66649 -1.187209   1.045950    -0.588275   0.681608    1.269271
# 66650  1.339997  -0.184404     1.613771  -1.700066   -0.280474
# 66651  1.046966   1.649154     0.203363  -0.509229   -0.435448
# 66652  1.113230   1.043079    -0.066145   1.078554   -0.667910
#
#        primary_call_reason_ord  agent_id_y  agent_tone  customer_tone  \
# 0             1.311437           1.547602   -0.334576    -0.710489
# 1            -1.646154          -0.176964    1.072477    -0.002877
# 2            -0.447131          -1.577935   -0.334576     1.412346
# 3             1.151567          -0.296320   -0.334576    -1.418100
# 4             0.671958           0.610142   -0.334576     1.412346
# ...                        ...         ...         ...            ...
# 66648        -0.287261           0.849804   -0.334576    -1.418100
# 66649         0.032479          -0.588275    1.072477     0.704734
# 66650         1.151567           1.613771    1.072477    -1.418100
# 66651         1.151567           0.203363    1.072477     1.412346
# 66652        -0.926740          -0.066145   -0.334576     0.704734
#
#        average_sentiment  silence_percent_average
# 0         -0.044345              0.544265
# 1          0.373215              0.336043
# 2         -0.670685              0.179876
# 3         -1.157839             -0.444792
# 4         -0.113938              0.336043
# ...                  ...                      ...
# 66648     -1.088246              1.168933
# 66649      0.581995              0.283987
# 66650      0.442809             -0.340681
# 66651      0.581995              0.700432
# 66652      0.234029             -0.965349
#
# [66653 rows x 11 columns]

# %%
# considering only those features which are numeric and in which numerical values given either continues or descrete

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['HandlingTime', 'WaitTime', 'silence_percent_average', 'primary_call_reason_ord']
x = 1

plt.figure(figsize=(10, 12))
for i in cols:
    sns.distplot(standard_scaler_merged_data[i], label=i)  # Add label to each plot
    plt.title(f"{i} Distribution")
    plt.tight_layout()
    plt.legend()  # Add the legend for the distribution
    x += 1

plt.show()

# %%
#  the above is the combined graph after applying the standardization and normalization so most of the values lies between -1 and 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['HandlingTime', 'WaitTime']
x = 1

plt.figure(figsize=(10, 12))
for i in cols:
    sns.distplot(standard_scaler_merged_data[i], label=i)  # Add label to each plot
    plt.title(f"{i} Distribution")
    plt.tight_layout()
    plt.legend()  # Add the legend for the distribution
    x += 1

plt.show()
